# %% [markdown]
# <a href="https://colab.research.google.com/github/Souzalua/ENG437--Ciencias-de-dados/blob/main/Estudo_de_Caso_aulas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ANALISE DE DBO
#
# **Programadora** - Luana Nascimento Barbosa Souza
#
# O projeto foi realizado a partir de um banco de dados coletado pela professora **Karla Esquerre**.
#
#
# Universidade Federal da Bahia- UFBA

# %% [markdown]
# ####**O objetivo do trabalho é predizer o comportamento da DBO de entrada**
# Com base no entendimento da proposta, buscamos agora entender como as variáveis se conectam com o nosso objetivo.
#
#
# *   Existe colinearidade entre as colunas do Data Frame e a DBO de entrada?
# *   Qual o comportamento das variáveis com o tempo?

# %% [markdown]
# Ao final da aula 2 você terá as seguintes habilidades:
# * Como subir um arquivo em um repositório no GitHub
# * Como importar um arquivo de um repositório no GitHub
# * Como importar um arquivo do Google Drive
# * Exploração de dados

# %% [markdown]
# # 1- Importando bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Importando database
#
# Exploração do banco de dados

# %%
#passo 1- carrega o link
link="https://github.com/Souzalua/ENG437--Ciencias-de-dados/raw/refs/heads/main/Dados%20Brutos.xlsx"
tabela=pd.read_excel(link)
display(tabela)
# Out:
#          Datein  FR(m3/dia)  BODin (ppm)  CODin (ppm)  SSin(ppm)  pHin  \
# 0    1996-09-01       79757        236.0        465.0        NaN  6.65
# 1    1996-09-02       78818        270.0        483.0        NaN  6.04
# 2    1996-09-03       82039        292.0        571.0        NaN  5.39
# 3    1996-09-04       79501        264.0        461.0        NaN  5.92
# 4    1996-09-05       82461        299.0        471.0      181.0  6.11
# ...         ...         ...          ...          ...        ...   ...
# 1425 2000-07-27       52215        367.0        751.0      250.0  7.44
# 1426 2000-07-28       53216        324.0        751.0      145.0  7.38
# 1427 2000-07-29       51561        344.0        701.0       96.0  7.36
# 1428 2000-07-30       51654        303.0        703.0      105.0  7.29
# 1429 2000-07-31       51662        324.0        689.0      118.0  7.28
#
#       NAmin(ppm)  NNin (ppm)  Pin (ppm)  Colin(ppm)  ...  Pap (ton/dia)  \
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
link="/content/drive/MyDrive/Ciencias de dados/Dados Brutos.xlsx"
tabela=pd.read_excel(link)
display(tabela)
# Out:
#          Datein  FR(m3/dia)  BODin (ppm)  CODin (ppm)  SSin(ppm)  pHin  \
# 0    1996-09-01       79757        236.0        465.0        NaN  6.65
# 1    1996-09-02       78818        270.0        483.0        NaN  6.04
# 2    1996-09-03       82039        292.0        571.0        NaN  5.39
# 3    1996-09-04       79501        264.0        461.0        NaN  5.92
# 4    1996-09-05       82461        299.0        471.0      181.0  6.11
# ...         ...         ...          ...          ...        ...   ...
# 1425 2000-07-27       52215        367.0        751.0      250.0  7.44
# 1426 2000-07-28       53216        324.0        751.0      145.0  7.38
# 1427 2000-07-29       51561        344.0        701.0       96.0  7.36
# 1428 2000-07-30       51654        303.0        703.0      105.0  7.29
# 1429 2000-07-31       51662        324.0        689.0      118.0  7.28
#
#       NAmin(ppm)  NNin (ppm)  Pin (ppm)  Colin(ppm)  ...  Pap (ton/dia)  \
# ...

# %% [markdown]
# Métodos de correlação
#
# ---
#
# method : {'pearson', 'kendall', 'spearman'}
#
#     * pearson : Correlação linear padrão- medirá o grau de linearidade entre duas variáveis. (Se os dados formam linha reta) -1 a 1
#
#     * kendall : Correlação Tau de Kendall-  Mede a força da relação baseada no ranqueamento dos dados. (conjuntos pequenos ou quando há valores repetidos)
#     * spearman : Também baseada em  ranks, mas foca na relação monotônica. Ou seja, se uma variável aumenta, a outra também aumenta, mesmo que não seja de forma linear. (categóricas ordinais x nominais)

# %% [markdown]
# Interpretando o valor de ρearson
#
# negativo implica que o aumento de uma leva a diminuição de outra
#
# 0.9 a 1 positivo ou negativo indica uma correlação muito forte.
#
# 0.7 a 0.9 positivo ou negativo indica uma correlação forte.
#
# 0.5 a 0.7 positivo ou negativo indica uma correlação moderada.
#
# 0.3 a 0.5 positivo ou negativo indica uma correlação fraca.
#
# 0 a 0.3 positivo ou negativo indica uma correlação desprezível
#
# nesse caso, os parâmetros que têm relação com a BDO são:
# BODin, CODin, colin,CODout

# %% [markdown]
# - Quais atributos melhor se correlacionam com a DBO de entrada, por quê?
# - A partir dessa análise inicial quais atributos você removeria da sua análise?
# - Como você trataria os outliers das colunas?
# - Quais hipóteses podem ser consideradas para dar seguimento ao estudo?
